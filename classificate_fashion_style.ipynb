# %% [markdown]
# <div class="alert alert-block alert-info"><h1 style="text-align:center;color:black"> Fashion style Classification Problem 📷 🚀 </h1> </div>
# The Dogs & Cats is a foundational problem for a basic CNN(convolutional neural network) model which involves classifying images as a fashion styles.The dataset can be used for learning how to develop,evaluate and use convolutional deep learning neural networks for classification of images. This includes how to develop a robust test harness for estimating the performance of the model, exploring improvements for the model by changing the paramters of the model, saving and loading the model to make predicitions on new data.
#
# Source: https://www.kaggle.com/datasets/paramaggarwal/fashion-product-images-dataset
#
# ![fashion](Datasets/fashion-dataset/dataset-cover.png)

# %% [markdown]
# <div class="alert alert-block alert-warning"><h2 style="text-align:Center;color:black">Table of Content </h2> </div>
#
# 1. [Introduction 💥](#1)
# 1. [Data Description](#2)
# 1. [Loading Libraries📖](#3)
# 1. [Data Extraction📁](#4)
# 1. [Data Exploration📊](#5)
# 1. [Train Test Split](#6)
#     1. [Using Dataframe](#7)
#     1. [Using Directory](#8)
# 1. [Data Preparation 🛠️](#9)
#     1. [Image Data Generator](#10)
#         1. [Using DataFrame](#11)
#         1. [Using Directory](#12)
# 1. [Deep learning Model ⚙️](#13)
#     1. [Model Layers](#14)
#     1. [Callbacks](#15)
#     1. [Compile Model](#23)
#     1. [Fit Model](#16)
#     1. [Plot Result](#17)
#     1. [Evaluvation](#18)
# 1. [Prediction](#19)
#     1. [Visualize Classified Images](#20)
# 1. [Submission](#21)
# 1. [Conclusion](#22)

# %% [markdown]
# <a id='1'></a>
# <div class="alert alert-block alert-danger"><h2 style="text-align:center;color:black"> Introduction 💥</h2> </div>
#
# In this notebook, we will discover how to develop a CNN to classify images of fashion_styles.
#
# We will follow this steps:
#
# * Load and prepare the images for training purpose.
# * Split data for training and validation purpose.
# * Apply Data Augmentation to the data.
# * Develop a CNN model using keras and how to choose various parameters for improving performance of the model.
# * Evaluate performance of our model.
# * Save and load a model for further predictions.
# * Draw the confusion matrix for trained model.

# %% [markdown]
# <a id='2'></a>
# <div class="alert alert-block alert-info"><h2 style="text-align:center;color:black"> Data Description </h2> </div>
#
# The training archive contains 44,110 images of fashion styles.
#
# Train your algorithm on these files and predict the labels.

# %% [markdown]
# <a id='3'></a>
# <div class="alert alert-block alert-info"><h2 style="text-align:center;color:black"> Loading Libraries </h2> </div>

# %%
# Basic
import warnings

warnings.filterwarnings('ignore')

import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

from os import makedirs
from os import listdir
from shutil import copyfile
from random import seed
from random import random
import numpy as np
import pandas as pd

# visuals
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread
from PIL import Image

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay

# Tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,MaxPooling2D,Dropout,Flatten,BatchNormalization,Conv2D
from tensorflow.keras.callbacks import ReduceLROnPlateau,EarlyStopping

# %%
#Define the source dir where the images come from
source = '../fashion_styles_recognition/Datasets/fashion-dataset/images'

# We will save in this dir the files we select to train the model
working_dir = '../fashion_styles_recognition/Datasets/fashion-dataset/working'

# We will classify in this dir the images classified by sytle
train_test_dir = '../fashion_styles_recognition/Datasets/fashion-dataset/train_test_styles/'

# We will classify in this dir the images classified by sytle
validate_dir = '../fashion_styles_recognition/Datasets/fashion-dataset/validate_styles/'

# %%
makedirs(working_dir, exist_ok=True)
makedirs(train_test_dir, exist_ok=True)
makedirs(validate_dir, exist_ok=True)

# %%
#We remove files of previous executions
for filename in os.listdir(working_dir):
    os.remove(os.path.join(working_dir, filename))

# %%
for dirname, _, filenames in os.walk(train_test_dir):
    for filename in filenames:
        os.remove(os.path.join(dirname, filename))

# %%
for dirname, _, filenames in os.walk(validate_dir):
    for filename in filenames:
        os.remove(os.path.join(dirname, filename))

# %% [markdown]
# <a id='4'></a>
# <div class="alert alert-block alert-info"><h2 style="text-align:center;color:black"> Data Extraction </h2> </div>

# %%
#We indicate where the data we will use is
files_dir = "../fashion_styles_recognition/Datasets/fashion-dataset/images/"

# %% [markdown]
# ### Loading Images in a Dataframe

# %%
#We create a dataframe with the info of the images in the datasets
csv_dir = "../fashion_styles_recognition/Datasets/fashion-dataset/"

data = pd.read_csv(csv_dir + "styles.csv", sep=";")

# %%
data.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt

# %%
#We review which categores we have in Mater category
data.masterCategory.unique()
# Out:
# array(['Apparel', 'Accessories', 'Footwear', 'Personal Care',
#        'Free Items', 'Sporting Goods', 'Home'], dtype=object)

# %%
data = data[data['masterCategory'] == 'Apparel']

# %%
#We review the article type
data.articleType.unique()
# Out:
# array(['Shirts', 'Jeans', 'Track Pants', 'Tshirts', 'Tops', 'Bra',
#        'Sweatshirts', 'Kurtas', 'Waistcoat', 'Shorts', 'Briefs', 'Sarees',
#        'Innerwear Vests', 'Rain Jacket', 'Dresses', 'Night suits',
#        'Skirts', 'Blazers', 'Kurta Sets', 'Shrug', 'Trousers',
#        'Camisoles', 'Boxers', 'Dupatta', 'Capris', 'Bath Robe', 'Tunics',
#        'Jackets', 'Trunk', 'Lounge Pants', 'Sweaters', 'Tracksuits',
#        'Swimwear', 'Nightdress', 'Baby Dolls', 'Leggings', 'Kurtis',
#        'Jumpsuit', 'Suspenders', 'Robe', 'Salwar and Dupatta', 'Patiala',
#        'Stockings', 'Tights', 'Churidar', 'Lounge Tshirts',
#        'Lounge Shorts', 'Shapewear', 'Nehru Jackets', 'Salwar',
#        'Jeggings', 'Rompers', 'Booties', 'Lehenga Choli', 'Clothing Set',
#        'Belts', 'Rain Trousers', 'Suits'], dtype=object)

# %%
# We erase all the types we don't need like underwear, socks, nightwear, etc
not_wanted = ['Bra','Briefs','Boxers','Innerwear Vests','Night suits','Baby Dolls','Nightdress','Swimwear','Suspenders','Robe','Stockings','Tights','Lounge Tshirts',
       'Lounge Shorts','Shapewear','Belts']

# %%
data = data[~data.articleType.isin(not_wanted)]

# %%
#Name of the file
data['filename_source'] = data['id'].astype(str) + '.jpg'

#Name of the style
data['label'] = data['usage']

#Origin route
data['source'] = source + '/' + data['filename_source']

#Filename in the destination route. It contains the label + id
data['filename_destination'] = data['usage'] + '.' + data['filename_source']

#We remove the cells we don't need
data.drop(labels=['gender', 'masterCategory', 'subCategory', 'articleType',
       'baseColour', 'season', 'year', 'usage', 'productDisplayName'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19283 entries, 0 to 44443
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    19283 non-null  int64
#  1   filename_source       19283 non-null  object
#  2   label                 19264 non-null  object
#  3   source                19283 non-null  object
#  4   filename_destination  19264 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 903.9+ KB

# %%
#We delete the registers whose label is null
data = data[data.label.notna()]

# %%
#We check if we actually have an image file for the registers
images = os.listdir(source)
data['exists'] = data.filename_source.isin(images)

data = data[data['exists'] == True]

data.drop(labels='exists', axis=1, inplace=True)

# %%
data.groupby('label').count()
# Out:
#                  id  filename_source  source  filename_destination
# label
# Casual        13569            13569   13569                 13569
# Ethnic         2960             2960    2960                  2960
# Formal         1129             1129    1129                  1129
# Party            22               22      22                    22
# Smart Casual     21               21      21                    21
# Sports         1557             1557    1557                  1557
# Travel            1                1       1                     1

# %%
# #Casual style has many registers. We select only 1610
casual_style = data[data['label'] == 'Casual'].sample(1610)
ethnic_style = data[data['label'] == 'Ethnic'].sample(1610)

# %%
#There are registers with only a few registers. We select only the styles with more than 1000
rest_styles = data[
    (data['label'] == 'Formal') |
    (data['label'] == 'Sports')
]

# %%
# We make a dataframe with the selected styles
data = pd.concat([casual_style, ethnic_style, rest_styles], ignore_index=True)

# %%
# We will need 5 files of each style to validate the model
Casual_validate = list(data[data['label'] == 'Casual']['id'].sample(5))
Ethnic_validate = list(data[data['label'] == 'Ethnic']['id'].sample(5))
Formal_validate = list(data[data['label'] == 'Formal']['id'].sample(5))
Sports_validate = list(data[data['label'] == 'Sports']['id'].sample(5))

# %%
# We generate list with 5 random id's of each style
# We aggregate all the ids of each style in one list
styles_validate = []

for style in [Casual_validate, Ethnic_validate, Formal_validate, Sports_validate]:
    styles_validate.extend(style)

# %%
# We will move the selected images for validation to the validation folder
# We will use the rest of images to train and test the model and we will move these images to the destination folder
data['destination'] = np.where(data['id'].isin(styles_validate),
                               validate_dir + data['filename_destination'],
                               working_dir + '/' + data['filename_destination'])

# %%
for i in data.index:
    src_path = data['source'][i]
    dst_path = data['destination'][i]
    copyfile(src_path, dst_path)

# %% [markdown]
# <a id='5'></a>
# <div class="alert alert-block alert-info"><h2 style="text-align:center;color:black"> Data Exploration </h2> </div>

# %% [markdown]
# First, we start by visualizing the variable of interest.
#
# Let's view more images in a grid format.
#
# <h5 style="text-align:center;color:Green">We visualize few images of Casual Style. </h5>

# %%
plt.figure(figsize=(20,20)) # specifying the overall grid size
plt.subplots_adjust(hspace=0.4)

df_label = data[data['label'] == 'Casual'][['destination']]
df_label.reset_index(drop=True, inplace=True)

for i in range(10):

    plt.subplot(1,10,i+1)    # the number of images in the grid is 10*10 (100)
    filename = df_label['destination'][i]
    image = imread(filename)
    plt.imshow(image)
    plt.title('Casual',fontsize=12)
    plt.axis('off')

plt.show()

# %% [markdown]
# <h5 style="text-align:center;color:Red">We visualize few images of Etnic style. </h5>

# %%
plt.figure(figsize=(20,20)) # specifying the overall grid size
plt.subplots_adjust(hspace=0.4)

df_label = data[data['label'] == 'Ethnic'][['destination']]
df_label.reset_index(drop=True, inplace=True)

for i in range(10):

    plt.subplot(1,10,i+1)    # the number of images in the grid is 10*10 (100)
    filename = df_label['destination'][i]
    image = imread(filename)
    plt.imshow(image)
    plt.title('Ethnic',fontsize=12)
    plt.axis('off')

plt.show()

# %% [markdown]
# <h5 style="text-align:center;color:Red">We visualize few images of Sports style. </h5>

# %%
plt.figure(figsize=(20,20)) # specifying the overall grid size
plt.subplots_adjust(hspace=0.4)

df_label = data[data['label'] == 'Sports'][['destination']]
df_label.reset_index(drop=True, inplace=True)

for i in range(10):

    plt.subplot(1,10,i+1)    # the number of images in the grid is 10*10 (100)
    filename = df_label['destination'][i]
    image = imread(filename)
    plt.imshow(image)
    plt.title('Sports',fontsize=12)
    plt.axis('off')

plt.show()

# %% [markdown]
# <h5 style="text-align:center;color:Red">We visualize few images of Formal style. </h5>

# %%
plt.figure(figsize=(20,20)) # specifying the overall grid size
plt.subplots_adjust(hspace=0.4)

df_label = data[data['label'] == 'Formal'][['destination']]
df_label.reset_index(drop=True, inplace=True)

for i in range(10):

    plt.subplot(1,10,i+1)    # the number of images in the grid is 10*10 (100)
    filename = df_label['destination'][i]
    image = imread(filename)
    plt.imshow(image)
    plt.title('Formal',fontsize=12)
    plt.axis('off')

plt.show()

# %% [markdown]
# Images are of varying size.
#
# Every time the cell is run different set of images will be displayed, one can scan the images of both categories. Presence of humans in some images could be a challenge for the model to classify.
#
# Some images have more than one cats or dogs respectively.

# %% [markdown]
# <a id='6'></a>
# <div class="alert alert-block alert-info"><h2 style="text-align:center;color:black"> Train Test Split </h2> </div>

# %% [markdown]
# <a id='7'></a>
# <div class="alert alert-block alert-warning"><h4 style="text-align:center;color:black"> Using Dataframe </h4> </div>

# %%
# train test split using dataframe

labels = data['label']

X_train, X_temp = train_test_split(data, test_size=0.2, stratify=labels, random_state = 42)

label_test_val = X_temp['label']

X_test, X_val = train_test_split(X_temp, test_size=0.5, stratify=label_test_val, random_state = 42)

print('The shape of train data',X_train.shape)
print('The shape of test data',X_test.shape)
print('The shape of validation data',X_val.shape)
# Out:
# The shape of train data (4724, 6)
# The shape of test data (591, 6)
# The shape of validation data (591, 6)

# %% [markdown]
# Now we will Create a barplot to see the class distrubtion in trainting dataset.

# %%
labels = list(data.label.unique())

label1,count1 = np.unique(X_train.label,return_counts=True)
label2,count2 = np.unique(X_val.label,return_counts=True)
label3,count3 = np.unique(X_test.label,return_counts=True)

uni1 = pd.DataFrame(data=count1,index=labels,columns=['Count1'])
uni2 = pd.DataFrame(data=count2,index=labels,columns=['Count2'])
uni3 = pd.DataFrame(data=count3,index=labels,columns=['Count3'])


plt.figure(figsize=(20,6),dpi=200)
sns.set_style('darkgrid')

plt.subplot(131)
sns.barplot(data=uni1,x=uni1.index,y='Count1',palette='icefire',width=0.2).set_title('Class distribution in Training set',fontsize=15)
plt.xlabel('Labels',fontsize=12)
plt.ylabel('Count',fontsize=12)

plt.subplot(132)
sns.barplot(data=uni2,x=uni2.index,y='Count2',palette='icefire',width=0.2).set_title('Class distribution in validation set',fontsize=15)
plt.xlabel('Labels',fontsize=12)
plt.ylabel('Count',fontsize=12)


plt.subplot(133)
sns.barplot(data=uni3,x=uni3.index,y='Count3',palette='icefire',width=0.2).set_title('Class distribution in Testing set',fontsize=15)
plt.xlabel('Labels',fontsize=12)
plt.ylabel('Count',fontsize=12)

plt.show()

# %% [markdown]
# <a id='8'></a>
# <div class="alert alert-block alert-warning"><h4 style="text-align:center;color:black"> Using Directory </h4> </div>

# %%
# create directories
subdirs = ['train/', 'test/']

# %%
for subdir in subdirs:
    # create label subdirectories
    labeldirs = []
    for label in labels:
        labeldirs.append(label + '/')
    for labldir in labeldirs:
        newdir = train_test_dir + subdir + labldir
        makedirs(newdir, exist_ok=True)

# %%
# seed random number generator
seed(1)
# define ratio of pictures to use for validation
val_ratio = 0.2

# %%
# copy training dataset images into subdirectories
src_directory = '../fashion_styles_recognition/Datasets/fashion-dataset/working'
for file in listdir(src_directory):
        src = src_directory + '/' + file
        dst_dir = 'train/'
        if random() < val_ratio:
            dst_dir = 'test/'
        if file.startswith('Casual'):
            dst = train_test_dir + dst_dir + 'Casual/' + file
            copyfile(src, dst)
        elif file.startswith('Ethnic'):
            dst = train_test_dir + dst_dir + 'Ethnic/' + file
            copyfile(src, dst)
        elif file.startswith('Formal'):
            dst = train_test_dir + dst_dir + 'Formal/' + file
            copyfile(src, dst)
        elif file.startswith('Sports'):
            dst = train_test_dir + dst_dir + 'Sports/' + file
            copyfile(src, dst)

# %%
path1 = "../fashion_styles_recognition/Datasets/fashion-dataset/train_test_styles/train/Casual"
path2 = "../fashion_styles_recognition/Datasets/fashion-dataset/train_test_styles/train/Ethnic"
path3 = "../fashion_styles_recognition/Datasets/fashion-dataset/train_test_styles/train/Formal"
path4 = "../fashion_styles_recognition/Datasets/fashion-dataset/train_test_styles/train/Sports"
path5 = "../fashion_styles_recognition/Datasets/fashion-dataset/train_test_styles/test/Casual"
path6 = "../fashion_styles_recognition/Datasets/fashion-dataset/train_test_styles/test/Ethnic"
path7 = "../fashion_styles_recognition/Datasets/fashion-dataset/train_test_styles/test/Formal"
path8 = "../fashion_styles_recognition/Datasets/fashion-dataset/train_test_styles/test/Sports"


print('Then number of Casual images in training data is' ,len(os.listdir(path1)))
print('Then number of Ethnic images in training data is' ,len(os.listdir(path2)))
print('Then number of Formal images in training data is' ,len(os.listdir(path3)))
print('Then number of Sports images in training data is' ,len(os.listdir(path4)))
print('Then number of Casual images in validation data is' ,len(os.listdir(path5)))
print('Then number of Ethnic images in validation data is' ,len(os.listdir(path6)))
print('Then number of Formal images in validation data is' ,len(os.listdir(path7)))
print('Then number of Sports images in validation data is' ,len(os.listdir(path8)))
# Out:
# Then number of Casual images in training data is 1307
# Then number of Ethnic images in training data is 1264
# Then number of Formal images in training data is 894
# Then number of Sports images in training data is 1252
# Then number of Casual images in validation data is 298
# Then number of Ethnic images in validation data is 341
# Then number of Formal images in validation data is 230
# Then number of Sports images in validation data is 300

# %% [markdown]
# <a id='9'></a>
# <div class="alert alert-block alert-info"><h2 style="text-align:center;color:black"> Data Preparation </h2> </div>
#
# firstly, we will list out all the important parameters and respective values.

# %%
# parameters
image_size = 128
image_channel = 3
bat_size = 32

# %% [markdown]
# <a id='10'></a>
# <div class="alert alert-block alert-danger"><h3 style="text-align:center;color:black">Image Data Generator </h3> </div>
#
# * The data for will used by flow_from_dataframe and flow_from_directory.
# * The batch size is 32 and the image size is (128,128).

# %%
# Creating image data generator
train_datagen = ImageDataGenerator(rescale=1./255,
                                    rotation_range = 15,
                                    horizontal_flip = True,
                                    zoom_range = 0.2,
                                    shear_range = 0.1,
                                    fill_mode = 'reflect',
                                    width_shift_range = 0.1,
                                    height_shift_range = 0.1)

test_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# <a id='11'></a>
# <div class="alert alert-block alert-warning"><h4 style="text-align:center;color:black"> Using Dataframe </h4> </div>

# %%
# Applying image data gernerator to train and test data

train_generator = train_datagen.flow_from_dataframe(X_train,
                                                    directory = '../fashion_styles_recognition/Datasets/fashion-dataset/working',
                                                    x_col= 'filename_destination',
                                                    y_col= 'label',
                                                    batch_size = bat_size,
                                                    target_size = (image_size,image_size)
                                                   )
val_generator = test_datagen.flow_from_dataframe(X_val,
                                                 directory = '../fashion_styles_recognition/Datasets/fashion-dataset/working',
                                                 x_col= 'filename_destination',
                                                 y_col= 'label',
                                                 batch_size = bat_size,
                                                 target_size = (image_size,image_size),
                                                 shuffle=False
                                                )

test_generator = test_datagen.flow_from_dataframe(X_test,
                                                  directory = '../fashion_styles_recognition/Datasets/fashion-dataset/working',
                                                  x_col= 'filename_destination',
                                                  y_col= 'label',
                                                  batch_size = bat_size,
                                                  target_size = (image_size,image_size),
                                                  shuffle=False
                                                 )
# Out:
# Found 4708 validated image filenames belonging to 4 classes.
# Found 588 validated image filenames belonging to 4 classes.
# Found 590 validated image filenames belonging to 4 classes.

# %% [markdown]
# <a id='12'></a>
# <div class="alert alert-block alert-warning"><h4 style="text-align:center;color:black"> Using Directory </h4> </div>

# %%
train_gen = train_datagen.flow_from_directory('../fashion_styles_recognition/Datasets/fashion-dataset/train_test_styles/train/',
                                              class_mode='binary',
                                              target_size = (image_size,image_size),
                                              batch_size = bat_size,
                                             )

val_gen = test_datagen.flow_from_directory('../fashion_styles_recognition/Datasets/fashion-dataset/train_test_styles/test/',
                                          class_mode='binary',
                                          batch_size = bat_size,
                                          target_size = (image_size,image_size),
                                          shuffle = False
                                         )
# Out:
# Found 4717 images belonging to 4 classes.
# Found 1169 images belonging to 4 classes.

# %% [markdown]
# <a id='13'></a>
# <div class="alert alert-block alert-info"><h2 style="text-align:center;color:black"> Deep Learning Model </h2> </div>

# %% [markdown]
# <a id='14'></a>
# <div class="alert alert-block alert-danger"><h3 style="text-align:center;color:black">Model Layers </h3> </div>
#
#
# ### Architecture
#
# The architecture of the Cat vs Dog Image Classification model consists of the following Layers and components:
#
# #### Layers :
# * The input layer consist of a Conv2D with 32 filters and activation relu.
# * The model contain the 3 blocks of convolution with increasing filters and activation relu.
# * Each convolution block contains Batch Noramlization, Max pooling (pool_size = 2) and Dropout (0.2).
# * The fully connected layers contain Flatten layer, Dense layer with 512 units and a Dropout layer.
# * The output layer is a Dense layer with 2 units and softmax activation.
#
# #### Components:
#
# * **Input Layer:** Receives input images for classification.
# * **Convolutional Layers:** Extract features from the images through convolutional operations.
# * **Pooling Layers:** Reduce the spatial dimensions of the feature maps.
# * **Flatten Layer:** Convert the 2D feature maps into a 1D vector.
# * **Fully Connected Layers:** Perform classification using densely connected layers.
# * **Output Layer:** Provides the final prediction probabilities for each fashion style classes.

# %%
model = Sequential()

# Input Layer
model.add(Conv2D(32,(3,3),activation='relu',input_shape = (image_size,image_size,image_channel)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Bloack 1
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
# Block 2
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
# Block 3
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Fully Connected layers
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# Output layer
model.add(Dense(4,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 126, 126, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 61, 61, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     4,719,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,113,540 (19.51 MB)
#  Trainable params: 5,111,556 (19.50 MB)
#  Non-trainable params: 1,984 (7.75 KB)

# %% [markdown]
# <a id='15'></a>
# <div class="alert alert-block alert-danger"><h3 style="text-align:center;color:black"> Callbacks </h3> </div>
# we will be using two callbacks -
#
# * **ReduceLROnPlateau :** Reduce learning rate when a metric has stopped improving.
# * **EarlyStopping :** Stop training when a monitored metric has stopped improving.

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy',
                                            patience=2,
                                            factor=0.5,
                                            min_lr = 0.00001,
                                            verbose = 1)

early_stoping = EarlyStopping(monitor='val_loss',patience= 3,restore_best_weights=True,verbose=0)

# %% [markdown]
# <a id='23'></a>
# <div class="alert alert-block alert-danger"><h3 style="text-align:center;color:black"> Compile the model </h3> </div>
# Finally we will compile the model .There are 3 things to mention here : Optimizer,Loss, Metrics
#
# * **Optimizer** :- To minimize cost function we use different methods For ex :- like gradient descent, stochastic gradient descent. So these are call optimizers. We are using a default one here which is adam.
# ​
# * **Loss** :- To make our model better we either minimize loss or maximize accuracy. Neural Networks always minimize loss. To measure it we can use different formulas like 'categorical_crossentropy' or 'binary_crossentropy'. Here I have used binary_crossentropy.
# ​
# * **Metrics** :- This is to denote the measure of your model. Can be accuracy or some other metric.

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# <a id='16'></a>
# <div class="alert alert-block alert-danger"><h3 style="text-align:center;color:black"> Fit the model </h3> </div>
#
# We are now going to train our compiled model using the train iterator (train_generator) and use the val iterator (val_generator) as a validation dataset during training.
#
# The number of steps for the train and validation iterators must be specified. This is the number of batches that will comprise one epoch. This can be specified via the length of each iterator, and will be the total number of images in the train and validation directories divided by the batch size (32).
#
# The model will be fit for 30 epochs.

# %%
styles_model = model.fit(train_generator,
                         validation_data = val_generator,
                         callbacks=[early_stoping,learning_rate_reduction],
                         epochs = 30,
                         # steps_per_epoch = len(train_generator),
                         # validation_steps = len(val_generaotor),
                         )
# Out:
# Epoch 1/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 6:47 3s/step - accuracy: 0.1562 - loss: 0.972 ━━━━━━━━━━━━━━━━━━━━ 1:31 629ms/step - accuracy: 0.2031 - loss: 1.04 ━━━━━━━━━━━━━━━━━━━━ 1:27 606ms/step - accuracy: 0.2326 - loss: 1.09 ━━━━━━━━━━━━━━━━━━━━ 1:25 593ms/step - accuracy: 0.2546 - loss: 1.11 ━━━━━━━━━━━━━━━━━━━━ 1:23 581ms/step - accuracy: 0.2774 - loss: 1.11 ━━━━━━━━━━━━━━━━━━━━ 1:21 573ms/step - accuracy: 0.2928 - loss: 1.10 ━━━━━━━━━━━━━━━━━━━━ 1:23 591ms/step - accuracy: 0.3065 - loss: 1.10 ━━━━━━━━━━━━━━━━━━━━ 1:22 587ms/step - accuracy: 0.3170 - loss: 1.09 ━━━━━━━━━━━━━━━━━━━━ 1:20 581ms/step - accuracy: 0.3253 - loss: 1.09 ━━━━━━━━━━━━━━━━━━━━ 1:19 577ms/step - accuracy: 0.3319 - loss: 1.08 ━━━━━━━━━━━━━━━━━━━━ 1:18 574ms/step - accuracy: 0.3379 - loss: 1.07 ━━━━━━━━━━━━━━━━━━━━ 1:18 580ms/step - accuracy: 0.3438 - loss: 1.06 ━━━━━━━━━━━━━━━━━━━━ 1:18 581ms/step - accuracy: 0.3499 - loss: 1.05 ━━━━━━━━━━━━━━━━━━━━ 1:17 576ms/step - accuracy: 0.3553 - loss: 1.04 ━━━━━━━━━━━━━━━━━━━━ 1:16 577ms/step - accuracy: 0.3605 - loss: 1.03 ━━━━━━━━━━━━━━━━━━━━ 1:16 576ms/step - accuracy: 0.3654 - loss: 1.03 ━━━━━━━━━━━━━━━━━━━━ 1:15 573ms/step - accuracy: 0.3699 - loss: 1.02 ━━━━━━━━━━━━━━━━━━━━ 1:14 572ms/step - accuracy: 0.3744 - loss: 1.01 ━━━━━━━━━━━━━━━━━━━━ 1:13 570ms/step - accuracy: 0.3787 - loss: 1.00 ━━━━━━━━━━━━━━━━━━━━ 1:12 568ms/step - accuracy: 0.3826 - loss: 0.99 ━━━━━━━━━━━━━━━━━━━━ 1:12 568ms/step - accuracy: 0.3863 - loss: 0.99 ━━━━━━━━━━━━━━━━━━━━ 1:11 569ms/step - accuracy: 0.3897 - loss: 0.98 ━━━━━━━━━━━━━━━━━━━━ 1:11 570ms/step - accuracy: 0.3931 - loss: 0.97 ━━━━━━━━━━━━━━━━━━━━ 1:10 571ms/step - accuracy: 0.3963 - loss: 0.96 ━━━━━━━━━━━━━━━━━━━━ 1:10 571ms/step - accuracy: 0.3994 - loss: 0.96 ━━━━━━━━━━━━━━━━━━━━ 1:07 551ms/step - accuracy: 0.4022 - loss: 0.95 ━━━━━━━━━━━━━━━━━━━━ 1:06 551ms/step - accuracy: 0.4049 - loss: 0.94 ━━━━━━━━━━━━━━━━━━━━ 1:06 551ms/step - accuracy: 0.4074 - loss: 0.94 ━━━━━━━━━━━━━━━━━━━━ 1:06 558ms/step - accuracy: 0.4098 - loss: 0.93 ━━━━━━━━━━━━━━━━━━━━ 1:05 558ms/step - accuracy: 0.4123 - loss: 0.93 ━━━━━━━━━━━━━━━━━━━━ 1:05 557ms/step - accuracy: 0.4144 - loss: 0.92 ━━━━━━━━━━━━━━━━━━━━ 1:04 557ms/step - accuracy: 0.4164 - loss: 0.91 ━━━━━━━━━━━━━━━━━━━━ 1:04 558ms/step - accuracy: 0.4182 - loss: 0.91 ━━━━━━━━━━━━━━━━━━━━ 1:03 559ms/step - accuracy: 0.4198 - loss: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1:03 559ms/step - accuracy: 0.4216 - loss: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1:02 560ms/step - accuracy: 0.4233 - loss: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1:02 559ms/step - accuracy: 0.4250 - loss: 0.89 ━━━━━━━━━━━━━━━━━━━━ 1:01 559ms/step - accuracy: 0.4266 - loss: 0.89 ━━━━━━━━━━━━━━━━━━━━ 1:00 559ms/step - accuracy: 0.4283 - loss: 0.88 ━━━━━━━━━━━━━━━━━━━━ 1:00 559ms/step - accuracy: 0.4299 - loss: 0.88 ━━━━━━━━━━━━━━━━━━━━ 59s 560ms/step - accuracy: 0.4315 - loss: 0.8788 ━━━━━━━━━━━━━━━━━━━━ 59s 560ms/step - accuracy: 0.4330 - loss: 0.874 ━━━━━━━━━━━━━━━━━━━━ 58s 561ms/step - accuracy: 0.4345 - loss: 0.870 ━━━━━━━━━━━━━━━━━━━━ 58s 561ms/step - accuracy: 0.4359 - loss: 0.866 ━━━━━━━━━━━━━━━━━━━━ 57s 561ms/step - accuracy: 0.4373 - loss: 0.862 ━━━━━━━━━━━━━━━━━━━━ 57s 560ms/step - accuracy: 0.4388 - loss: 0.859 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - accuracy: 0.4402 - loss: 0.855 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - accuracy: 0.4416 - loss: 0.851 ━━━━━━━━━━━━━━━━━━━━ 55s 560ms/step - accuracy: 0.4431 - loss: 0.848 ━━━━━━━━━━━━━━━━━━━━ 54s 560ms/step - accuracy: 0.4444 - loss: 0.844 ━━━━━━━━━━━━━━━━━━━━ 54s 560ms/step - accuracy: 0.4457 - loss: 0.841 ━━━━━━━━━━━━━━━━━━━━ 53s 561ms/step - accuracy: 0.4469 - loss: 0.837 ━━━━━━━━━━━━━━━━━━━━ 53s 561ms/step - accuracy: 0.4481 - loss: 0.834 ━━━━━━━━━━━━━━━━━━━━ 52s 561ms/step - accuracy: 0.4493 - loss: 0.831 ━━━━━━━━━━━━━━━━━━━━ 52s 562ms/step - accuracy: 0.4505 - loss: 0.828 ━━━━━━━━━━━━━━━━━━━━ 51s 562ms/step - accuracy: 0.4516 - loss: 0.825 ━━━━━━━━━━━━━━━━━━━━ 51s 562ms/step - accuracy: 0.4528 - loss: 0.822 ━━━━━━━━━━━━━━━━━━━━ 50s 562ms/step - accuracy: 0.4538 - los ...
# Epoch 2/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1:48 737ms/step - accuracy: 0.6562 - loss: 0.35 ━━━━━━━━━━━━━━━━━━━━ 1:11 492ms/step - accuracy: 0.6328 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:15 523ms/step - accuracy: 0.6233 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:13 513ms/step - accuracy: 0.6159 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:17 540ms/step - accuracy: 0.6152 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:17 546ms/step - accuracy: 0.6099 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:17 549ms/step - accuracy: 0.6070 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:16 543ms/step - accuracy: 0.6058 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:15 541ms/step - accuracy: 0.6064 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:13 535ms/step - accuracy: 0.6067 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:13 537ms/step - accuracy: 0.6078 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:13 542ms/step - accuracy: 0.6082 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:12 540ms/step - accuracy: 0.6085 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:11 536ms/step - accuracy: 0.6092 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:10 533ms/step - accuracy: 0.6107 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:10 536ms/step - accuracy: 0.6118 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:10 539ms/step - accuracy: 0.6133 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:10 539ms/step - accuracy: 0.6147 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:09 538ms/step - accuracy: 0.6160 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:09 544ms/step - accuracy: 0.6176 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:09 544ms/step - accuracy: 0.6188 - loss: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:05 522ms/step - accuracy: 0.6200 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:05 522ms/step - accuracy: 0.6211 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:04 521ms/step - accuracy: 0.6222 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:04 521ms/step - accuracy: 0.6232 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:03 520ms/step - accuracy: 0.6243 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:02 520ms/step - accuracy: 0.6255 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:02 523ms/step - accuracy: 0.6265 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:02 522ms/step - accuracy: 0.6274 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:01 523ms/step - accuracy: 0.6282 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:01 523ms/step - accuracy: 0.6290 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:00 522ms/step - accuracy: 0.6297 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:00 522ms/step - accuracy: 0.6305 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 59s 523ms/step - accuracy: 0.6314 - loss: 0.4008 ━━━━━━━━━━━━━━━━━━━━ 59s 523ms/step - accuracy: 0.6323 - loss: 0.400 ━━━━━━━━━━━━━━━━━━━━ 58s 525ms/step - accuracy: 0.6331 - loss: 0.399 ━━━━━━━━━━━━━━━━━━━━ 58s 525ms/step - accuracy: 0.6338 - loss: 0.399 ━━━━━━━━━━━━━━━━━━━━ 57s 526ms/step - accuracy: 0.6343 - loss: 0.398 ━━━━━━━━━━━━━━━━━━━━ 57s 525ms/step - accuracy: 0.6348 - loss: 0.398 ━━━━━━━━━━━━━━━━━━━━ 56s 524ms/step - accuracy: 0.6353 - loss: 0.398 ━━━━━━━━━━━━━━━━━━━━ 56s 525ms/step - accuracy: 0.6357 - loss: 0.397 ━━━━━━━━━━━━━━━━━━━━ 55s 525ms/step - accuracy: 0.6360 - loss: 0.397 ━━━━━━━━━━━━━━━━━━━━ 55s 525ms/step - accuracy: 0.6365 - loss: 0.397 ━━━━━━━━━━━━━━━━━━━━ 54s 525ms/step - accuracy: 0.6369 - loss: 0.396 ━━━━━━━━━━━━━━━━━━━━ 53s 524ms/step - accuracy: 0.6372 - loss: 0.396 ━━━━━━━━━━━━━━━━━━━━ 53s 524ms/step - accuracy: 0.6376 - loss: 0.396 ━━━━━━━━━━━━━━━━━━━━ 52s 524ms/step - accuracy: 0.6379 - loss: 0.396 ━━━━━━━━━━━━━━━━━━━━ 52s 526ms/step - accuracy: 0.6382 - loss: 0.395 ━━━━━━━━━━━━━━━━━━━━ 52s 527ms/step - accuracy: 0.6385 - loss: 0.395 ━━━━━━━━━━━━━━━━━━━━ 51s 527ms/step - accuracy: 0.6389 - loss: 0.395 ━━━━━━━━━━━━━━━━━━━━ 51s 528ms/step - accuracy: 0.6393 - loss: 0.395 ━━━━━━━━━━━━━━━━━━━━ 50s 529ms/step - accuracy: 0.6396 - loss: 0.395 ━━━━━━━━━━━━━━━━━━━━ 50s 529ms/step - accuracy: 0.6399 - loss: 0.395 ━━━━━━━━━━━━━━━━━━━━ 49s 529ms/step - accuracy: 0.6401 - loss: 0.394 ━━━━━━━━━━━━━━━━━━━━ 49s 529ms/step - accuracy: 0.6404 - loss: 0.394 ━━━━━━━━━━━━━━━━━━━━ 48s 529ms/step - accuracy: 0.6406 - loss: 0.394 ━━━━━━━━━━━━━━━━━━━━ 48s 528ms/step - accuracy: 0.6408 - loss: 0.394 ━━━━━━━━━━━━━━━━━━━━ 47s 529ms/step - accuracy: 0.6411 - l ...
# Epoch 3/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1:35 650ms/step - accuracy: 0.5938 - loss: 0.34 ━━━━━━━━━━━━━━━━━━━━ 1:22 562ms/step - accuracy: 0.5703 - loss: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:18 540ms/step - accuracy: 0.5642 - loss: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:22 576ms/step - accuracy: 0.5736 - loss: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:22 575ms/step - accuracy: 0.5801 - loss: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:19 557ms/step - accuracy: 0.5867 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:19 560ms/step - accuracy: 0.5941 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:17 554ms/step - accuracy: 0.5999 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:16 553ms/step - accuracy: 0.6042 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:15 547ms/step - accuracy: 0.6088 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:13 539ms/step - accuracy: 0.6126 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:13 537ms/step - accuracy: 0.6152 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:12 538ms/step - accuracy: 0.6176 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:12 540ms/step - accuracy: 0.6199 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:11 539ms/step - accuracy: 0.6220 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:11 540ms/step - accuracy: 0.6239 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:10 541ms/step - accuracy: 0.6259 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:10 544ms/step - accuracy: 0.6282 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:10 544ms/step - accuracy: 0.6299 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:09 544ms/step - accuracy: 0.6317 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:08 541ms/step - accuracy: 0.6335 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:08 540ms/step - accuracy: 0.6352 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:07 540ms/step - accuracy: 0.6370 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:06 538ms/step - accuracy: 0.6388 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:06 541ms/step - accuracy: 0.6406 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:05 539ms/step - accuracy: 0.6420 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:05 539ms/step - accuracy: 0.6432 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:04 539ms/step - accuracy: 0.6444 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:04 540ms/step - accuracy: 0.6456 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:03 541ms/step - accuracy: 0.6467 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:03 540ms/step - accuracy: 0.6477 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:02 540ms/step - accuracy: 0.6487 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:02 540ms/step - accuracy: 0.6496 - loss: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:01 541ms/step - accuracy: 0.6505 - loss: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:01 541ms/step - accuracy: 0.6513 - loss: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:00 541ms/step - accuracy: 0.6521 - loss: 0.37 ━━━━━━━━━━━━━━━━━━━━ 59s 540ms/step - accuracy: 0.6529 - loss: 0.3784 ━━━━━━━━━━━━━━━━━━━━ 59s 540ms/step - accuracy: 0.6536 - loss: 0.378 ━━━━━━━━━━━━━━━━━━━━ 58s 540ms/step - accuracy: 0.6544 - loss: 0.377 ━━━━━━━━━━━━━━━━━━━━ 58s 539ms/step - accuracy: 0.6551 - loss: 0.377 ━━━━━━━━━━━━━━━━━━━━ 57s 540ms/step - accuracy: 0.6557 - loss: 0.377 ━━━━━━━━━━━━━━━━━━━━ 57s 540ms/step - accuracy: 0.6564 - loss: 0.376 ━━━━━━━━━━━━━━━━━━━━ 56s 540ms/step - accuracy: 0.6572 - loss: 0.376 ━━━━━━━━━━━━━━━━━━━━ 56s 540ms/step - accuracy: 0.6579 - loss: 0.375 ━━━━━━━━━━━━━━━━━━━━ 55s 541ms/step - accuracy: 0.6586 - loss: 0.375 ━━━━━━━━━━━━━━━━━━━━ 55s 541ms/step - accuracy: 0.6591 - loss: 0.375 ━━━━━━━━━━━━━━━━━━━━ 54s 540ms/step - accuracy: 0.6597 - loss: 0.374 ━━━━━━━━━━━━━━━━━━━━ 54s 540ms/step - accuracy: 0.6602 - loss: 0.374 ━━━━━━━━━━━━━━━━━━━━ 53s 539ms/step - accuracy: 0.6608 - loss: 0.373 ━━━━━━━━━━━━━━━━━━━━ 52s 539ms/step - accuracy: 0.6613 - loss: 0.373 ━━━━━━━━━━━━━━━━━━━━ 52s 540ms/step - accuracy: 0.6617 - loss: 0.373 ━━━━━━━━━━━━━━━━━━━━ 51s 539ms/step - accuracy: 0.6622 - loss: 0.372 ━━━━━━━━━━━━━━━━━━━━ 51s 539ms/step - accuracy: 0.6627 - loss: 0.372 ━━━━━━━━━━━━━━━━━━━━ 50s 541ms/step - accuracy: 0.6631 - loss: 0.372 ━━━━━━━━━━━━━━━━━━━━ 50s 541ms/step - accuracy: 0.6635 - loss: 0.371 ━━━━━━━━━━━━━━━━━━━━ 49s 540ms/step - accuracy: 0.6639 - loss: 0.371 ━━━━━━━━━━━━━━━━━━━━ 49s 540ms/step - accuracy: 0.6643 - loss: 0.371 ━━━━━━━━━━━━━━━━━━━━ 48s 541ms/step - accuracy: 0.6647 - l ...
# Epoch 4/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1:47 729ms/step - accuracy: 0.7188 - loss: 0.28 ━━━━━━━━━━━━━━━━━━━━ 1:11 488ms/step - accuracy: 0.7031 - loss: 0.29 ━━━━━━━━━━━━━━━━━━━━ 1:20 554ms/step - accuracy: 0.7014 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:20 557ms/step - accuracy: 0.6979 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:19 555ms/step - accuracy: 0.6971 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:17 544ms/step - accuracy: 0.6972 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:17 546ms/step - accuracy: 0.7003 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:15 542ms/step - accuracy: 0.7021 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:15 544ms/step - accuracy: 0.7020 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:14 541ms/step - accuracy: 0.7021 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:13 539ms/step - accuracy: 0.7024 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:13 544ms/step - accuracy: 0.7035 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:13 545ms/step - accuracy: 0.7051 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:12 540ms/step - accuracy: 0.7068 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:11 538ms/step - accuracy: 0.7089 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:10 534ms/step - accuracy: 0.7107 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:10 536ms/step - accuracy: 0.7119 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:09 532ms/step - accuracy: 0.7128 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:08 530ms/step - accuracy: 0.7135 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:07 529ms/step - accuracy: 0.7145 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:07 532ms/step - accuracy: 0.7151 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:07 533ms/step - accuracy: 0.7159 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:06 534ms/step - accuracy: 0.7165 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:06 535ms/step - accuracy: 0.7169 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:06 537ms/step - accuracy: 0.7172 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:05 538ms/step - accuracy: 0.7174 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:05 539ms/step - accuracy: 0.7176 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:04 539ms/step - accuracy: 0.7176 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:04 540ms/step - accuracy: 0.7176 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:03 539ms/step - accuracy: 0.7176 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:02 537ms/step - accuracy: 0.7176 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:02 537ms/step - accuracy: 0.7176 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:01 536ms/step - accuracy: 0.7178 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:01 536ms/step - accuracy: 0.7180 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 1:00 536ms/step - accuracy: 0.7182 - loss: 0.31 ━━━━━━━━━━━━━━━━━━━━ 59s 535ms/step - accuracy: 0.7184 - loss: 0.3114 ━━━━━━━━━━━━━━━━━━━━ 59s 538ms/step - accuracy: 0.7186 - loss: 0.311 ━━━━━━━━━━━━━━━━━━━━ 59s 538ms/step - accuracy: 0.7189 - loss: 0.311 ━━━━━━━━━━━━━━━━━━━━ 58s 539ms/step - accuracy: 0.7192 - loss: 0.311 ━━━━━━━━━━━━━━━━━━━━ 58s 538ms/step - accuracy: 0.7194 - loss: 0.311 ━━━━━━━━━━━━━━━━━━━━ 57s 538ms/step - accuracy: 0.7196 - loss: 0.312 ━━━━━━━━━━━━━━━━━━━━ 57s 538ms/step - accuracy: 0.7197 - loss: 0.312 ━━━━━━━━━━━━━━━━━━━━ 56s 538ms/step - accuracy: 0.7198 - loss: 0.312 ━━━━━━━━━━━━━━━━━━━━ 55s 538ms/step - accuracy: 0.7200 - loss: 0.312 ━━━━━━━━━━━━━━━━━━━━ 55s 539ms/step - accuracy: 0.7201 - loss: 0.312 ━━━━━━━━━━━━━━━━━━━━ 55s 540ms/step - accuracy: 0.7201 - loss: 0.312 ━━━━━━━━━━━━━━━━━━━━ 54s 539ms/step - accuracy: 0.7201 - loss: 0.312 ━━━━━━━━━━━━━━━━━━━━ 53s 539ms/step - accuracy: 0.7202 - loss: 0.313 ━━━━━━━━━━━━━━━━━━━━ 53s 539ms/step - accuracy: 0.7202 - loss: 0.313 ━━━━━━━━━━━━━━━━━━━━ 52s 538ms/step - accuracy: 0.7203 - loss: 0.313 ━━━━━━━━━━━━━━━━━━━━ 52s 539ms/step - accuracy: 0.7204 - loss: 0.313 ━━━━━━━━━━━━━━━━━━━━ 51s 539ms/step - accuracy: 0.7205 - loss: 0.313 ━━━━━━━━━━━━━━━━━━━━ 51s 540ms/step - accuracy: 0.7205 - loss: 0.313 ━━━━━━━━━━━━━━━━━━━━ 50s 539ms/step - accuracy: 0.7206 - loss: 0.313 ━━━━━━━━━━━━━━━━━━━━ 50s 539ms/step - accuracy: 0.7206 - loss: 0.313 ━━━━━━━━━━━━━━━━━━━━ 48s 531ms/step - accuracy: 0.7206 - loss: 0.313 ━━━━━━━━━━━━━━━━━━━━ 48s 531ms/step - accuracy: 0.7206 - loss: 0.314 ━━━━━━━━━━━━━━━━━━━━ 47s 530ms/step - accuracy: 0.7207 - l ...
# Epoch 5/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1:38 667ms/step - accuracy: 0.5938 - loss: 0.45 ━━━━━━━━━━━━━━━━━━━━ 1:22 566ms/step - accuracy: 0.6406 - loss: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:22 571ms/step - accuracy: 0.6493 - loss: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:21 564ms/step - accuracy: 0.6569 - loss: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:19 559ms/step - accuracy: 0.6655 - loss: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:18 551ms/step - accuracy: 0.6744 - loss: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:17 547ms/step - accuracy: 0.6826 - loss: 0.35 ━━━━━━━━━━━━━━━━━━━━ 1:18 561ms/step - accuracy: 0.6891 - loss: 0.35 ━━━━━━━━━━━━━━━━━━━━ 1:18 562ms/step - accuracy: 0.6943 - loss: 0.34 ━━━━━━━━━━━━━━━━━━━━ 1:17 565ms/step - accuracy: 0.6990 - loss: 0.34 ━━━━━━━━━━━━━━━━━━━━ 1:17 562ms/step - accuracy: 0.7031 - loss: 0.33 ━━━━━━━━━━━━━━━━━━━━ 1:16 563ms/step - accuracy: 0.7061 - loss: 0.33 ━━━━━━━━━━━━━━━━━━━━ 1:15 562ms/step - accuracy: 0.7082 - loss: 0.33 ━━━━━━━━━━━━━━━━━━━━ 1:14 558ms/step - accuracy: 0.7102 - loss: 0.33 ━━━━━━━━━━━━━━━━━━━━ 1:14 561ms/step - accuracy: 0.7116 - loss: 0.33 ━━━━━━━━━━━━━━━━━━━━ 1:14 561ms/step - accuracy: 0.7122 - loss: 0.33 ━━━━━━━━━━━━━━━━━━━━ 1:13 559ms/step - accuracy: 0.7127 - loss: 0.33 ━━━━━━━━━━━━━━━━━━━━ 1:12 560ms/step - accuracy: 0.7136 - loss: 0.33 ━━━━━━━━━━━━━━━━━━━━ 1:11 558ms/step - accuracy: 0.7143 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:10 554ms/step - accuracy: 0.7148 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:10 556ms/step - accuracy: 0.7150 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:10 557ms/step - accuracy: 0.7152 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:10 560ms/step - accuracy: 0.7154 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:09 560ms/step - accuracy: 0.7156 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:08 558ms/step - accuracy: 0.7158 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:08 559ms/step - accuracy: 0.7163 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:07 561ms/step - accuracy: 0.7167 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:07 560ms/step - accuracy: 0.7170 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:06 558ms/step - accuracy: 0.7170 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:05 557ms/step - accuracy: 0.7172 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:05 556ms/step - accuracy: 0.7173 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:04 555ms/step - accuracy: 0.7175 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:03 555ms/step - accuracy: 0.7176 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:03 555ms/step - accuracy: 0.7178 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:02 557ms/step - accuracy: 0.7181 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:02 557ms/step - accuracy: 0.7184 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:01 556ms/step - accuracy: 0.7187 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:01 555ms/step - accuracy: 0.7191 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:00 554ms/step - accuracy: 0.7194 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 1:00 556ms/step - accuracy: 0.7198 - loss: 0.32 ━━━━━━━━━━━━━━━━━━━━ 59s 556ms/step - accuracy: 0.7201 - loss: 0.3249 ━━━━━━━━━━━━━━━━━━━━ 58s 554ms/step - accuracy: 0.7203 - loss: 0.324 ━━━━━━━━━━━━━━━━━━━━ 58s 553ms/step - accuracy: 0.7207 - loss: 0.324 ━━━━━━━━━━━━━━━━━━━━ 57s 553ms/step - accuracy: 0.7211 - loss: 0.324 ━━━━━━━━━━━━━━━━━━━━ 57s 554ms/step - accuracy: 0.7215 - loss: 0.324 ━━━━━━━━━━━━━━━━━━━━ 56s 555ms/step - accuracy: 0.7219 - loss: 0.323 ━━━━━━━━━━━━━━━━━━━━ 56s 555ms/step - accuracy: 0.7222 - loss: 0.323 ━━━━━━━━━━━━━━━━━━━━ 55s 556ms/step - accuracy: 0.7224 - loss: 0.323 ━━━━━━━━━━━━━━━━━━━━ 54s 555ms/step - accuracy: 0.7227 - loss: 0.323 ━━━━━━━━━━━━━━━━━━━━ 54s 555ms/step - accuracy: 0.7230 - loss: 0.323 ━━━━━━━━━━━━━━━━━━━━ 53s 554ms/step - accuracy: 0.7233 - loss: 0.323 ━━━━━━━━━━━━━━━━━━━━ 53s 554ms/step - accuracy: 0.7235 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 52s 555ms/step - accuracy: 0.7238 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 52s 556ms/step - accuracy: 0.7241 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 51s 557ms/step - accuracy: 0.7243 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 51s 556ms/step - accuracy: 0.7246 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 50s 556ms/step - accuracy: 0.7248 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 50s 557ms/step - accuracy: 0.7251 - l ...
# Epoch 6/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1:45 714ms/step - accuracy: 0.7188 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:28 604ms/step - accuracy: 0.7266 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:19 550ms/step - accuracy: 0.7413 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 56s 390ms/step - accuracy: 0.7510 - loss: 0.2505 ━━━━━━━━━━━━━━━━━━━━ 1:01 428ms/step - accuracy: 0.7569 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:03 450ms/step - accuracy: 0.7598 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:05 468ms/step - accuracy: 0.7628 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:07 480ms/step - accuracy: 0.7655 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:07 486ms/step - accuracy: 0.7647 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:07 488ms/step - accuracy: 0.7653 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:06 487ms/step - accuracy: 0.7670 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:06 487ms/step - accuracy: 0.7677 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:06 490ms/step - accuracy: 0.7687 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:05 491ms/step - accuracy: 0.7692 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:05 493ms/step - accuracy: 0.7691 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:05 496ms/step - accuracy: 0.7687 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:04 496ms/step - accuracy: 0.7677 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:04 499ms/step - accuracy: 0.7669 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:04 498ms/step - accuracy: 0.7664 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:03 498ms/step - accuracy: 0.7658 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:03 499ms/step - accuracy: 0.7655 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:03 503ms/step - accuracy: 0.7653 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:03 504ms/step - accuracy: 0.7649 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:02 507ms/step - accuracy: 0.7646 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:02 507ms/step - accuracy: 0.7643 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:01 508ms/step - accuracy: 0.7639 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:01 507ms/step - accuracy: 0.7637 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:00 507ms/step - accuracy: 0.7634 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:00 508ms/step - accuracy: 0.7629 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:00 510ms/step - accuracy: 0.7624 - loss: 0.27 ━━━━━━━━━━━━━━━━━━━━ 59s 511ms/step - accuracy: 0.7619 - loss: 0.2712 ━━━━━━━━━━━━━━━━━━━━ 59s 510ms/step - accuracy: 0.7616 - loss: 0.271 ━━━━━━━━━━━━━━━━━━━━ 58s 509ms/step - accuracy: 0.7613 - loss: 0.272 ━━━━━━━━━━━━━━━━━━━━ 58s 512ms/step - accuracy: 0.7611 - loss: 0.272 ━━━━━━━━━━━━━━━━━━━━ 58s 514ms/step - accuracy: 0.7609 - loss: 0.273 ━━━━━━━━━━━━━━━━━━━━ 57s 517ms/step - accuracy: 0.7607 - loss: 0.273 ━━━━━━━━━━━━━━━━━━━━ 57s 516ms/step - accuracy: 0.7604 - loss: 0.274 ━━━━━━━━━━━━━━━━━━━━ 56s 515ms/step - accuracy: 0.7602 - loss: 0.274 ━━━━━━━━━━━━━━━━━━━━ 56s 515ms/step - accuracy: 0.7601 - loss: 0.275 ━━━━━━━━━━━━━━━━━━━━ 55s 515ms/step - accuracy: 0.7599 - loss: 0.275 ━━━━━━━━━━━━━━━━━━━━ 55s 515ms/step - accuracy: 0.7597 - loss: 0.276 ━━━━━━━━━━━━━━━━━━━━ 54s 516ms/step - accuracy: 0.7596 - loss: 0.276 ━━━━━━━━━━━━━━━━━━━━ 54s 516ms/step - accuracy: 0.7594 - loss: 0.277 ━━━━━━━━━━━━━━━━━━━━ 53s 517ms/step - accuracy: 0.7592 - loss: 0.277 ━━━━━━━━━━━━━━━━━━━━ 53s 518ms/step - accuracy: 0.7590 - loss: 0.277 ━━━━━━━━━━━━━━━━━━━━ 52s 519ms/step - accuracy: 0.7588 - loss: 0.278 ━━━━━━━━━━━━━━━━━━━━ 52s 521ms/step - accuracy: 0.7586 - loss: 0.278 ━━━━━━━━━━━━━━━━━━━━ 52s 523ms/step - accuracy: 0.7584 - loss: 0.279 ━━━━━━━━━━━━━━━━━━━━ 51s 524ms/step - accuracy: 0.7583 - loss: 0.279 ━━━━━━━━━━━━━━━━━━━━ 51s 525ms/step - accuracy: 0.7581 - loss: 0.280 ━━━━━━━━━━━━━━━━━━━━ 51s 526ms/step - accuracy: 0.7580 - loss: 0.280 ━━━━━━━━━━━━━━━━━━━━ 50s 526ms/step - accuracy: 0.7579 - loss: 0.280 ━━━━━━━━━━━━━━━━━━━━ 49s 526ms/step - accuracy: 0.7578 - loss: 0.281 ━━━━━━━━━━━━━━━━━━━━ 49s 526ms/step - accuracy: 0.7577 - loss: 0.281 ━━━━━━━━━━━━━━━━━━━━ 48s 525ms/step - accuracy: 0.7577 - loss: 0.281 ━━━━━━━━━━━━━━━━━━━━ 48s 525ms/step - accuracy: 0.7576 - loss: 0.281 ━━━━━━━━━━━━━━━━━━━━ 47s 527ms/step - accuracy: 0.7575 - loss: 0.282 ━━━━━━━━━━━━━━━━━━━━ 47s 527ms/step - accuracy: 0.7575 -  ...
# Epoch 7/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1:49 745ms/step - accuracy: 0.7188 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:17 530ms/step - accuracy: 0.7656 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:22 569ms/step - accuracy: 0.7708 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:21 565ms/step - accuracy: 0.7812 - loss: 0.23 ━━━━━━━━━━━━━━━━━━━━ 1:20 565ms/step - accuracy: 0.7887 - loss: 0.23 ━━━━━━━━━━━━━━━━━━━━ 1:20 564ms/step - accuracy: 0.7936 - loss: 0.23 ━━━━━━━━━━━━━━━━━━━━ 1:18 557ms/step - accuracy: 0.7969 - loss: 0.23 ━━━━━━━━━━━━━━━━━━━━ 1:17 551ms/step - accuracy: 0.7989 - loss: 0.23 ━━━━━━━━━━━━━━━━━━━━ 1:16 548ms/step - accuracy: 0.7992 - loss: 0.23 ━━━━━━━━━━━━━━━━━━━━ 1:14 542ms/step - accuracy: 0.7996 - loss: 0.23 ━━━━━━━━━━━━━━━━━━━━ 1:13 537ms/step - accuracy: 0.7979 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:13 538ms/step - accuracy: 0.7968 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:12 536ms/step - accuracy: 0.7965 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:11 536ms/step - accuracy: 0.7964 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:11 540ms/step - accuracy: 0.7959 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:11 539ms/step - accuracy: 0.7951 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:11 542ms/step - accuracy: 0.7941 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:10 540ms/step - accuracy: 0.7928 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:09 536ms/step - accuracy: 0.7918 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:08 535ms/step - accuracy: 0.7912 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:07 533ms/step - accuracy: 0.7903 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:07 533ms/step - accuracy: 0.7895 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:06 533ms/step - accuracy: 0.7886 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:05 531ms/step - accuracy: 0.7880 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:05 531ms/step - accuracy: 0.7874 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:04 530ms/step - accuracy: 0.7869 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:04 533ms/step - accuracy: 0.7865 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:04 534ms/step - accuracy: 0.7860 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:03 533ms/step - accuracy: 0.7856 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:02 533ms/step - accuracy: 0.7853 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:02 533ms/step - accuracy: 0.7849 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:01 534ms/step - accuracy: 0.7845 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:01 535ms/step - accuracy: 0.7842 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:01 537ms/step - accuracy: 0.7839 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:00 538ms/step - accuracy: 0.7836 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:00 539ms/step - accuracy: 0.7834 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 59s 540ms/step - accuracy: 0.7831 - loss: 0.2639 ━━━━━━━━━━━━━━━━━━━━ 59s 539ms/step - accuracy: 0.7829 - loss: 0.264 ━━━━━━━━━━━━━━━━━━━━ 58s 539ms/step - accuracy: 0.7827 - loss: 0.264 ━━━━━━━━━━━━━━━━━━━━ 58s 539ms/step - accuracy: 0.7825 - loss: 0.264 ━━━━━━━━━━━━━━━━━━━━ 57s 538ms/step - accuracy: 0.7824 - loss: 0.264 ━━━━━━━━━━━━━━━━━━━━ 57s 539ms/step - accuracy: 0.7822 - loss: 0.264 ━━━━━━━━━━━━━━━━━━━━ 56s 539ms/step - accuracy: 0.7820 - loss: 0.265 ━━━━━━━━━━━━━━━━━━━━ 56s 539ms/step - accuracy: 0.7818 - loss: 0.265 ━━━━━━━━━━━━━━━━━━━━ 55s 538ms/step - accuracy: 0.7816 - loss: 0.265 ━━━━━━━━━━━━━━━━━━━━ 54s 537ms/step - accuracy: 0.7814 - loss: 0.265 ━━━━━━━━━━━━━━━━━━━━ 54s 536ms/step - accuracy: 0.7811 - loss: 0.266 ━━━━━━━━━━━━━━━━━━━━ 53s 537ms/step - accuracy: 0.7808 - loss: 0.266 ━━━━━━━━━━━━━━━━━━━━ 53s 538ms/step - accuracy: 0.7805 - loss: 0.266 ━━━━━━━━━━━━━━━━━━━━ 52s 537ms/step - accuracy: 0.7803 - loss: 0.266 ━━━━━━━━━━━━━━━━━━━━ 52s 538ms/step - accuracy: 0.7801 - loss: 0.266 ━━━━━━━━━━━━━━━━━━━━ 51s 537ms/step - accuracy: 0.7799 - loss: 0.267 ━━━━━━━━━━━━━━━━━━━━ 51s 538ms/step - accuracy: 0.7796 - loss: 0.267 ━━━━━━━━━━━━━━━━━━━━ 50s 538ms/step - accuracy: 0.7794 - loss: 0.267 ━━━━━━━━━━━━━━━━━━━━ 50s 538ms/step - accuracy: 0.7792 - loss: 0.267 ━━━━━━━━━━━━━━━━━━━━ 49s 538ms/step - accuracy: 0.7790 - loss: 0.267 ━━━━━━━━━━━━━━━━━━━━ 48s 537ms/step - accuracy: 0.7788 - loss: 0.268 ━━━━━━━━━━━━━━━━━━━━ 48s 538ms/step - accuracy: 0.7786 - l ...
# Epoch 8/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1:42 700ms/step - accuracy: 0.9375 - loss: 0.17 ━━━━━━━━━━━━━━━━━━━━ 1:16 521ms/step - accuracy: 0.8750 - loss: 0.22 ━━━━━━━━━━━━━━━━━━━━ 1:17 537ms/step - accuracy: 0.8542 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:17 537ms/step - accuracy: 0.8477 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:15 528ms/step - accuracy: 0.8406 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:15 529ms/step - accuracy: 0.8351 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:14 526ms/step - accuracy: 0.8318 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:13 527ms/step - accuracy: 0.8304 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:12 523ms/step - accuracy: 0.8273 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:13 530ms/step - accuracy: 0.8261 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:12 531ms/step - accuracy: 0.8249 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:12 530ms/step - accuracy: 0.8230 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:11 530ms/step - accuracy: 0.8209 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:10 530ms/step - accuracy: 0.8193 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:10 527ms/step - accuracy: 0.8177 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:09 528ms/step - accuracy: 0.8158 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:09 530ms/step - accuracy: 0.8142 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:08 528ms/step - accuracy: 0.8128 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:08 527ms/step - accuracy: 0.8115 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:07 530ms/step - accuracy: 0.8102 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:07 528ms/step - accuracy: 0.8093 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:06 528ms/step - accuracy: 0.8085 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:06 530ms/step - accuracy: 0.8075 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:05 532ms/step - accuracy: 0.8067 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:05 535ms/step - accuracy: 0.8059 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:05 535ms/step - accuracy: 0.8053 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:04 535ms/step - accuracy: 0.8046 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:04 534ms/step - accuracy: 0.8038 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:03 534ms/step - accuracy: 0.8033 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:03 537ms/step - accuracy: 0.8029 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:02 537ms/step - accuracy: 0.8025 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:02 538ms/step - accuracy: 0.8021 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:01 538ms/step - accuracy: 0.8016 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:01 538ms/step - accuracy: 0.8011 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:00 539ms/step - accuracy: 0.8007 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:00 539ms/step - accuracy: 0.8003 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 59s 540ms/step - accuracy: 0.7999 - loss: 0.2605 ━━━━━━━━━━━━━━━━━━━━ 59s 542ms/step - accuracy: 0.7997 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 59s 542ms/step - accuracy: 0.7994 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 58s 542ms/step - accuracy: 0.7992 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 58s 542ms/step - accuracy: 0.7991 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 57s 542ms/step - accuracy: 0.7989 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 56s 542ms/step - accuracy: 0.7988 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 56s 543ms/step - accuracy: 0.7986 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 55s 543ms/step - accuracy: 0.7984 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 55s 544ms/step - accuracy: 0.7983 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 54s 544ms/step - accuracy: 0.7982 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 54s 544ms/step - accuracy: 0.7980 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 53s 544ms/step - accuracy: 0.7978 - loss: 0.261 ━━━━━━━━━━━━━━━━━━━━ 53s 544ms/step - accuracy: 0.7977 - loss: 0.261 ━━━━━━━━━━━━━━━━━━━━ 51s 535ms/step - accuracy: 0.7976 - loss: 0.261 ━━━━━━━━━━━━━━━━━━━━ 51s 536ms/step - accuracy: 0.7974 - loss: 0.261 ━━━━━━━━━━━━━━━━━━━━ 50s 535ms/step - accuracy: 0.7973 - loss: 0.261 ━━━━━━━━━━━━━━━━━━━━ 50s 535ms/step - accuracy: 0.7972 - loss: 0.261 ━━━━━━━━━━━━━━━━━━━━ 49s 533ms/step - accuracy: 0.7971 - loss: 0.261 ━━━━━━━━━━━━━━━━━━━━ 49s 533ms/step - accuracy: 0.7970 - loss: 0.261 ━━━━━━━━━━━━━━━━━━━━ 48s 534ms/step - accuracy: 0.7968 - loss: 0.261 ━━━━━━━━━━━━━━━━━━━━ 48s 535ms/step - accuracy: 0.7967 - l ...
# Epoch 9/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1:46 726ms/step - accuracy: 0.7500 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:19 547ms/step - accuracy: 0.7500 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:17 535ms/step - accuracy: 0.7431 - loss: 0.27 ━━━━━━━━━━━━━━━━━━━━ 1:16 532ms/step - accuracy: 0.7448 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:15 530ms/step - accuracy: 0.7496 - loss: 0.27 ━━━━━━━━━━━━━━━━━━━━ 1:15 530ms/step - accuracy: 0.7549 - loss: 0.27 ━━━━━━━━━━━━━━━━━━━━ 1:14 530ms/step - accuracy: 0.7605 - loss: 0.27 ━━━━━━━━━━━━━━━━━━━━ 1:15 537ms/step - accuracy: 0.7656 - loss: 0.27 ━━━━━━━━━━━━━━━━━━━━ 1:14 538ms/step - accuracy: 0.7700 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:14 540ms/step - accuracy: 0.7733 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:14 545ms/step - accuracy: 0.7761 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:14 544ms/step - accuracy: 0.7781 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:13 546ms/step - accuracy: 0.7792 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:13 549ms/step - accuracy: 0.7805 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:12 547ms/step - accuracy: 0.7815 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:12 550ms/step - accuracy: 0.7821 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:12 551ms/step - accuracy: 0.7827 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:11 550ms/step - accuracy: 0.7831 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:10 550ms/step - accuracy: 0.7834 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:10 548ms/step - accuracy: 0.7838 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:09 549ms/step - accuracy: 0.7840 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:09 549ms/step - accuracy: 0.7840 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:08 546ms/step - accuracy: 0.7841 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:07 546ms/step - accuracy: 0.7844 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:07 546ms/step - accuracy: 0.7845 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:06 546ms/step - accuracy: 0.7846 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:05 544ms/step - accuracy: 0.7845 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:05 542ms/step - accuracy: 0.7844 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:04 543ms/step - accuracy: 0.7844 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:04 545ms/step - accuracy: 0.7844 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:03 546ms/step - accuracy: 0.7843 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:03 547ms/step - accuracy: 0.7842 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:02 547ms/step - accuracy: 0.7842 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:02 546ms/step - accuracy: 0.7842 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:01 546ms/step - accuracy: 0.7842 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:01 546ms/step - accuracy: 0.7842 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 59s 533ms/step - accuracy: 0.7842 - loss: 0.2607 ━━━━━━━━━━━━━━━━━━━━ 58s 534ms/step - accuracy: 0.7842 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 58s 533ms/step - accuracy: 0.7842 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 57s 534ms/step - accuracy: 0.7842 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 57s 534ms/step - accuracy: 0.7841 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 56s 535ms/step - accuracy: 0.7840 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 56s 535ms/step - accuracy: 0.7840 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 55s 534ms/step - accuracy: 0.7839 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 55s 534ms/step - accuracy: 0.7838 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 54s 534ms/step - accuracy: 0.7836 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 53s 534ms/step - accuracy: 0.7835 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 53s 534ms/step - accuracy: 0.7833 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 52s 534ms/step - accuracy: 0.7832 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 52s 534ms/step - accuracy: 0.7831 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 51s 534ms/step - accuracy: 0.7830 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 51s 534ms/step - accuracy: 0.7829 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 50s 535ms/step - accuracy: 0.7829 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 50s 535ms/step - accuracy: 0.7828 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 49s 536ms/step - accuracy: 0.7828 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 49s 537ms/step - accuracy: 0.7828 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 48s 536ms/step - accuracy: 0.7828 - loss: 0.260 ━━━━━━━━━━━━━━━━━━━━ 48s 537ms/step - accuracy: 0.7828 - l ...
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 88s 594ms/step - accuracy: 0.7809 - loss: 0.2623 - val_accuracy: 0.4966 - val_loss: 0.6296 - learning_rate: 0.0010
# Epoch 10/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1:53 771ms/step - accuracy: 0.6875 - loss: 0.30 ━━━━━━━━━━━━━━━━━━━━ 1:16 525ms/step - accuracy: 0.7422 - loss: 0.28 ━━━━━━━━━━━━━━━━━━━━ 1:13 504ms/step - accuracy: 0.7622 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:12 504ms/step - accuracy: 0.7669 - loss: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:13 511ms/step - accuracy: 0.7735 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:12 512ms/step - accuracy: 0.7774 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:13 518ms/step - accuracy: 0.7780 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:13 524ms/step - accuracy: 0.7784 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:12 525ms/step - accuracy: 0.7779 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:12 525ms/step - accuracy: 0.7786 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:12 530ms/step - accuracy: 0.7788 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:12 532ms/step - accuracy: 0.7801 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:11 529ms/step - accuracy: 0.7811 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:10 528ms/step - accuracy: 0.7819 - loss: 0.25 ━━━━━━━━━━━━━━━━━━━━ 1:09 524ms/step - accuracy: 0.7829 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:09 524ms/step - accuracy: 0.7837 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:08 524ms/step - accuracy: 0.7841 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:08 523ms/step - accuracy: 0.7844 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:07 522ms/step - accuracy: 0.7850 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:06 521ms/step - accuracy: 0.7854 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:06 523ms/step - accuracy: 0.7857 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:06 527ms/step - accuracy: 0.7862 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:05 528ms/step - accuracy: 0.7867 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:05 528ms/step - accuracy: 0.7873 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:04 527ms/step - accuracy: 0.7877 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:04 530ms/step - accuracy: 0.7881 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:04 530ms/step - accuracy: 0.7884 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:03 530ms/step - accuracy: 0.7887 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:03 529ms/step - accuracy: 0.7888 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:02 531ms/step - accuracy: 0.7891 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:02 531ms/step - accuracy: 0.7894 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:01 532ms/step - accuracy: 0.7896 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:01 532ms/step - accuracy: 0.7899 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:00 531ms/step - accuracy: 0.7903 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 1:00 533ms/step - accuracy: 0.7905 - loss: 0.24 ━━━━━━━━━━━━━━━━━━━━ 59s 533ms/step - accuracy: 0.7908 - loss: 0.2456 ━━━━━━━━━━━━━━━━━━━━ 59s 532ms/step - accuracy: 0.7910 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 58s 532ms/step - accuracy: 0.7912 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 57s 532ms/step - accuracy: 0.7915 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 57s 533ms/step - accuracy: 0.7917 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 57s 534ms/step - accuracy: 0.7920 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 56s 534ms/step - accuracy: 0.7922 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 56s 533ms/step - accuracy: 0.7924 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 55s 533ms/step - accuracy: 0.7926 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 54s 534ms/step - accuracy: 0.7927 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 54s 533ms/step - accuracy: 0.7929 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 53s 533ms/step - accuracy: 0.7931 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 53s 533ms/step - accuracy: 0.7932 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 52s 533ms/step - accuracy: 0.7933 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 52s 533ms/step - accuracy: 0.7935 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 51s 534ms/step - accuracy: 0.7937 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 51s 534ms/step - accuracy: 0.7939 - loss: 0.245 ━━━━━━━━━━━━━━━━━━━━ 50s 534ms/step - accuracy: 0.7940 - loss: 0.244 ━━━━━━━━━━━━━━━━━━━━ 50s 535ms/step - accuracy: 0.7941 - loss: 0.244 ━━━━━━━━━━━━━━━━━━━━ 49s 535ms/step - accuracy: 0.7943 - loss: 0.244 ━━━━━━━━━━━━━━━━━━━━ 49s 535ms/step - accuracy: 0.7944 - loss: 0.244 ━━━━━━━━━━━━━━━━━━━━ 48s 535ms/step - accuracy: 0.7944 - loss: 0.244 ━━━━━━━━━━━━━━━━━━━━ 48s 535ms/step - accuracy: 0.7945 - l ...

# %% [markdown]
# <a id='17'></a>
# <div class="alert alert-block alert-danger"><h3 style="text-align:center;color:black"> Plot the results </h3> </div>

# %%
# plots for accuracy and Loss with epochs

error = pd.DataFrame(styles_model.history)

plt.figure(figsize=(18,5),dpi=200)
sns.set_style('darkgrid')

plt.subplot(121)
plt.title('Cross Entropy Loss',fontsize=15)
plt.xlabel('Epochs',fontsize=12)
plt.ylabel('Loss',fontsize=12)
plt.plot(error['loss'])
plt.plot(error['val_loss'])

plt.subplot(122)
plt.title('Classification Accuracy',fontsize=15)
plt.xlabel('Epochs',fontsize=12)
plt.ylabel('Accuracy',fontsize=12)
plt.plot(error['accuracy'])
plt.plot(error['val_accuracy'])

plt.show()

# %% [markdown]
# <a id='18'></a>
# <div class="alert alert-block alert-danger"><h3 style="text-align:center;color:black"> Evaluvation </h3> </div>
#
# we will evaluvate the Training and validation data accuracy and loss.

# %%
# Evaluvate for train generator
loss,acc = model.evaluate(train_generator,batch_size = bat_size, verbose = 0)

print('The accuracy of the model for training data is:',acc*100)
print('The Loss of the model for training data is:',loss)

# Evaluvate for validation generator
loss,acc = model.evaluate(val_generator,batch_size = bat_size, verbose = 0)

print('The accuracy of the model for validation data is:',acc*100)
print('The Loss of the model for validation data is:',loss)
# Out:
# The accuracy of the model for training data is: 64.33729529380798
# The Loss of the model for training data is: 0.389464408159256
# The accuracy of the model for validation data is: 69.04761791229248
# The Loss of the model for validation data is: 0.36877378821372986

# %% [markdown]
# Finally, we will save the model for future use.

# %%
# Save the Model
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# <a id='19'></a>
# <div class="alert alert-block alert-info"><h2 style="text-align:center;color:black"> Prediction </h2> </div>
#
# Now, we will predict the model on test dataset.

# %%
# prediction
result = model.predict(test_generator,batch_size = bat_size,verbose = 0)

y_pred = np.argmax(result, axis = 1)

y_true = test_generator.labels

# Evaluvate
loss,acc = model.evaluate(test_generator, batch_size = bat_size, verbose = 0)

print('The accuracy of the model for testing data is:',acc*100)
print('The Loss of the model for testing data is:',loss)
# Out:
# The accuracy of the model for testing data is: 72.37288355827332
# The Loss of the model for testing data is: 0.35793906450271606

# %% [markdown]
# Classification report

# %%
print(classification_report(y_true, y_pred,target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#       Casual       0.81      0.41      0.54       160
#       Ethnic       0.95      0.66      0.78       161
#       Formal       0.66      0.97      0.79       113
#       Sports       0.63      0.94      0.75       156
#
#     accuracy                           0.72       590
#    macro avg       0.76      0.74      0.71       590
# weighted avg       0.77      0.72      0.71       590

# %% [markdown]
# confusioin matrix

# %%
confusion_mtx = confusion_matrix(y_true,y_pred)

f,ax = plt.subplots(figsize = (8,4),dpi=200)
sns.heatmap(confusion_mtx, annot=True, linewidths=0.1, cmap = "gist_yarg_r", linecolor="black", fmt='.0f', ax=ax,cbar=False, xticklabels=labels, yticklabels=labels)

plt.xlabel("Predicted Label",fontsize=10)
plt.ylabel("True Label",fontsize=10)
plt.title("Confusion Matrix",fontsize=13)

plt.show()

# %% [markdown]
# <a id='20'></a>
# <div class="alert alert-block alert-info"><h2 style="text-align:center;color:black"> submission </h2> </div>
# Make predictions on kaggle test data for submission.

# %%
size =(128,128)

# loading into dataframe
filenames = os.listdir(validate_dir)
test_data = pd.DataFrame({"filename": filenames})
test_data['label'] = 'unknown'

# %%
# Create data genenerator for test data
test1_idg =  test_datagen.flow_from_dataframe(test_data,
                                     "../fashion_styles_recognition/Datasets/fashion-dataset/validate_styles/",
                                     x_col= "filename",
                                     y_col = 'label',
                                     batch_size = bat_size,
                                     target_size=size,
                                     shuffle = False)

# Test Prediction
test1_predict = model.predict(test1_idg,verbose = 0)

test1_predict_argmax = np.argmax(test1_predict, axis=1)

y_test_pred = test1_predict_argmax

test_data['label'] = y_test_pred
# Out:
# Found 20 validated image filenames belonging to 1 classes.

# %%
# mapping
label_mapping = {0: 'Casual', 1: 'Ethnic', 2: 'Formal', 3: 'Sports',}
test_data['label'] = test_data['label'].map(label_mapping)
test_data.head()
# Out:
#            filename   label
# 0  Casual.11395.jpg  Sports
# 1  Casual.19834.jpg  Casual
# 2  Casual.21405.jpg  Casual
# 3   Casual.4876.jpg  Sports
# 4  Casual.51401.jpg  Casual

# %%
# csv file output for submission
# sub = pd.read_csv('../fashion_styles_recognition/Datasets/sampleSubmission.csv',index_col='id')

sub = pd.DataFrame(columns = ['id','label'])

sub['id'] = test_data['filename']
sub['label'] = y_test_pred

sub.to_csv('../fashion_styles_recognition/Datasets/submission.csv',index=True)

# %% [markdown]
# <a id='21'></a>
# <div class="alert alert-block alert-danger"><h3 style="text-align:center;color:black"> Visualize Classified Images  </h3> </div>

# %%
fig, axes = plt.subplots(1, 20, figsize=(40, 4))
for idx in range(20):
    image_path = os.path.join(validate_dir, test_data.iloc[idx]['filename'])
    image = Image.open(image_path)
    axes[idx].imshow(image)
    axes[idx].set_title("Label: " + test_data.iloc[idx]['label'])
    axes[idx].axis('off')
plt.show()

# %% [markdown]
# <a id='22'></a>
# <div class="alert alert-block alert-info"><h2 style="text-align:center;color:black"> Conclusion </h2> </div>
#
#
# We successfully built a deep neural network model by implementing Convolutional Neural Network (CNN) to classify dog and cat images with very high accuracy 72.3 %.
#
# The model was used to predict the classes of the images from the independent test set and results were submitted to test the accuracy of the prediction with fresh data.
#
# The Fashion Stykes Classification model demonstrates the successful implementation of a Convolutional Neural Network for image classification tasks. By accurately distinguishing between images of different styles, this project showcases the potential of deep learning algorithms in solving real-world problems involving image analysis. Through this project, we aim to inspire further exploration of CNNs and their applications in various domains.
